# %% [markdown]
# ### All Top TFs

# %%
! python seq_saliency_scores.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/hESC_universal_5kb_8_tracks_KO_fix_mask.ckpt \
    --chr chr11 \
    --start 31000000 \
    --seq ../cshark_data/data/hg19/dna_sequence \
    --bigwigs ctcf=../cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/ctcf.bw \
              atac=../cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/atac.bw \
    --target-locus "chr11:31760000-31860000_chr11:32380000-32480000" \
    --resolution 4096 \
    --matrix-size 512 \
    --out-dir tmp \
    --ctcf-ko \
    --n-motifs 5
# Out:
# Using device: cpu
# Loading data for region chr11:31000000...
# Knocking out CTCF peaks in the input region...
# Loading model...
# Preprocessing input data...
# Performing forward pass...
# Maximizing score for pixel region: rows[185:209], cols[336:361]
# Initial score for target locus: 1163.291748046875
# Performing backward pass to get gradients...
# Calculated saliency scores. Max score: 3.7704795598983765, Mean score: 0.021459443145713363
# 100%|█████████████████████████████████████████| 720/720 [02:51<00:00,  4.21it/s]
#   motif  pos_100bp    pos  score_fw  score_rc
# 0  ALX3       5700   5798 -0.051418 -0.040183
# 1  ALX3       5800   5804 -0.039859 -0.050456
# 2  ALX3      19400  19452  0.062862  0.057547
# 3  ALX3      19500  19591  0.101114  0.092399
# 4  ALX3      19600  19607  0.054763  0.050259
# Top motifs correlated with saliency scores:
#     motif  pos_100bp      pos  score_fw  score_rc  corr_max  corr_min
# 0  ZBTB14     821100   821199  3.209885  2.346066  3.209885  2.346066
# 1   SATB1    1251700  1251799  3.006727  2.612674  3.006727  2.612674
# 2   VEZF1    1460900  1460999  2.035146  2.975545  2.975545  2.035146
# 3  ZNF417    1461300  1461399  2.331099  2.624633  2.624633  2.331099
# 4   VEZF1     819900   819999  0.725764  2.594260  2.594260  0.725764
# 5  ZNF281    1245100  1245199 -0.274152  0.369992  0.369992 -0.274152
# 6  PLAGL2    1206100  1206199 -0.089176 -0.180151 -0.089176 -0.180151
# 7  ZNF384    1197300  1197399 -0.044138 -0.149152 -0.044138 -0.149152
# 8   PROP1     808900   808999 -0.128447 -0.131932 -0.128447 -0.131932
# 9    ATF7    1007800  1007800 -0.122335 -0.129771 -0.122335 -0.129771
#     motif  pos_100bp      pos  score_fw  score_rc  corr_max  corr_min
# 0  ZBTB14     821100   821199  3.209885  2.346066  3.209885  2.346066
# 1   SATB1    1251700  1251799  3.006727  2.612674  3.006727  2.612674
# 2   VEZF1    1460900  1460999  2.035146  2.975545  2.975545  2.035146
# 3  ZNF417    1461300  1461399  2.331099  2.624633  2.624633  2.331099
# 4   VEZF1     819900   819999  0.725764  2.594260  2.594260  0.725764
# 5  ZNF281    1245100  1245199 -0.274152  0.369992  0.369992 -0.274152
# 6  PLAGL2    1206100  1206199 -0.089176 -0.180151 -0.089176 -0.180151
# 7  ZNF384    1197300  1197399 -0.044138 -0.149152 -0.044138 -0.149152
# 8   PROP1     808900   808999 -0.128447 -0.131932 -0.128447 -0.131932
# 9    ATF7    1007800  1007800 -0.122335 -0.129771 -0.122335 -0.129771
# Saving attribution scores...
# (2097152, 5)
# Mean change in target locus after inserting motif ZBTB14 at pos 821100: 0.01
# Mean change in target locus after inserting motif SATB1 at pos 1251700: 0.01
# Mean change in target locus after inserting motif VEZF1 at pos 1460900: -0.00
# Mean change in target locus after inserting motif ZNF417 at pos 1461300: -0.00
# Mean change in target locus after inserting motif VEZF1 at pos 819900: -0.00
# Mean change in target locus after inserting motif ZNF281 at pos 1245100: -0.00
# Mean change in target locus after inserting motif PLAGL2 at pos 1206100: 0.00
# Mean change in target locus after inserting motif ZNF384 at pos 1197300: -0.00
# Mean change in target locus after inserting motif PROP1 at pos 808900: -0.01
# Mean change in target locus after inserting motif ATF7 at pos 1007800: 0.00

# %% [markdown]
# ### Only single TF

# %%
! python seq_saliency_scores.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/hESC_universal_5kb_8_tracks_KO_fix_mask.ckpt \
    --chr chr11 \
    --start 31000000 \
    --seq ../cshark_data/data/hg19/dna_sequence \
    --bigwigs ctcf=../cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/ctcf.bw \
              atac=../cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/atac.bw \
    --target-locus "chr11:31760000-31860000_chr11:32380000-32480000" \
    --resolution 4096 \
    --matrix-size 512 \
    --out-dir tmp \
    --ctcf-ko \
    --tf SATB1 \
    --n-motifs 1
# Out:
# Using device: cpu
# Loading data for region chr11:31000000...
# Knocking out CTCF peaks in the input region...
# Loading model...
# Using 11 encoder blocks based on target_mat_size=512.
# Using 11 encoder blocks based on target_mat_size=512.
# Preprocessing input data...
# Performing forward pass...
# Maximizing score for pixel region: rows[185:209], cols[336:361]
# Initial score for target locus: 421.0774841308594
# Performing backward pass to get gradients...
# Calculated saliency scores. Max score: 1.0979032255709171, Mean score: 0.007142464367054266
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.04it/s]
#    motif  pos_100bp    pos  score_fw  score_rc
# 0  SATB1      18000  18086  0.047874  0.051215
# 1  SATB1      23000  23089  0.052076  0.042328
# 2  SATB1      26100  26183  0.059748  0.072688
# 3  SATB1      31900  31966  0.050156  0.048574
# 4  SATB1      33600  33640  0.067914  0.069935
# Top motifs correlated with saliency scores:
#    motif  pos_100bp     pos  score_fw  score_rc  corr_max  corr_min
# 0  SATB1     993300  993399  0.798058  0.886213  0.886213  0.798058
# 1  SATB1     779300  779303 -0.037614 -0.068700 -0.037614 -0.068700
#    motif  pos_100bp     pos  score_fw  score_rc  corr_max  corr_min
# 0  SATB1     993300  993399  0.798058  0.886213  0.886213  0.798058
# 1  SATB1     779300  779303 -0.037614 -0.068700 -0.037614 -0.068700
# Saving attribution scores...
# (2097152, 5)
# Mean change in target locus after inserting motif SATB1 at pos 993300: 0.00
# Mean change in target locus after inserting motif SATB1 at pos 779300: 0.00

# %% [markdown]
# ### Use HOCOMOCO instead of JASPAR

# %%
! python seq_saliency_scores.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/hESC_universal_5kb_8_tracks_KO_fix_mask.ckpt \
    --chr chr11 \
    --start 31000000 \
    --seq ../cshark_data/data/hg19/dna_sequence \
    --bigwigs ctcf=../cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/ctcf.bw \
              atac=../cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/atac.bw \
    --target-locus "chr11:31760000-31860000_chr11:32380000-32480000" \
    --resolution 4096 \
    --matrix-size 512 \
    --ctcf-ko \
    --out-dir tmp \
    --meme-file /home/dmp131/C.Shark/src/cshark/static/HOCOMOCOv11_full_HUMAN_mono_meme_format.meme \
    --n-motifs 5
# Out:
# Using device: cpu
# Loading data for region chr11:31000000...
# Knocking out CTCF peaks in the input region...
# Loading model...
# Preprocessing input data...
# Performing forward pass...
# Maximizing score for pixel region: rows[185:209], cols[336:361]
# Initial score for target locus: 1163.291748046875
# Performing backward pass to get gradients...
# Calculated saliency scores. Max score: 3.7704795598983765, Mean score: 0.021459443145713363
# Successfully parsed 769 motifs from /home/dmp131/C.Shark/src/cshark/static/HOCOMOCOv11_full_HUMAN_mono_meme_format.meme
# 100%|█████████████████████████████████████████| 769/769 [03:06<00:00,  4.13it/s]
#                  motif  pos_100bp    pos  score_fw  score_rc
# 0  AHR_HUMAN.H11MO.0.B       5700   5781  0.082640  0.085100
# 1  AHR_HUMAN.H11MO.0.B      19500  19587  0.057578  0.054096
# 2  AHR_HUMAN.H11MO.0.B      19600  19636  0.056663  0.035703
# 3  AHR_HUMAN.H11MO.0.B      19700  19798  0.040579  0.047248
# 4  AHR_HUMAN.H11MO.0.B      19800  19800 -0.054310  0.025388
# Top motifs correlated with saliency scores:
#                    motif  pos_100bp      pos  ...  score_rc  corr_max  corr_min
# 0  ZBT14_HUMAN.H11MO.0.C     821100   821199  ...  3.092221  3.092221  2.545761
# 1  PRRX2_HUMAN.H11MO.0.C    1251700  1251799  ...  2.454970  2.581447  2.454970
# 2  ZBT14_HUMAN.H11MO.0.C    1460900  1460999  ...  2.437409  2.525616  2.437409
# 3  ZBT14_HUMAN.H11MO.0.C    1462700  1462791  ...  2.163961  2.163961  1.874410
# 4   E2F5_HUMAN.H11MO.0.B    1461300  1461399  ...  2.109352  2.109352  1.416897
# 5  TBX15_HUMAN.H11MO.0.D    1245100  1245199  ...  0.057167  0.057167 -0.164354
# 6    SP2_HUMAN.H11MO.0.A    1206100  1206199  ... -0.158145 -0.015642 -0.158145
# 7    SP1_HUMAN.H11MO.0.A    1206000  1206099  ...  0.113581  0.113581 -0.138450
# 8   UNC4_HUMAN.H11MO.0.D     808900   808999  ... -0.132150 -0.117586 -0.132150
# 9   NFIB_HUMAN.H11MO.0.D     781500   781500  ... -0.122356  0.009504 -0.122356
#
# [10 rows x 7 columns]
#                    motif  pos_100bp      pos  ...  score_rc  corr_max  corr_min
# 0  ZBT14_HUMAN.H11MO.0.C     821100   821199  ...  3.092221  3.092221  2.545761
# 1  PRRX2_HUMAN.H11MO.0.C    1251700  1251799  ...  2.454970  2.581447  2.454970
# 2  ZBT14_HUMAN.H11MO.0.C    1460900  1460999  ...  2.437409  2.525616  2.437409
# 3  ZBT14_HUMAN.H11MO.0.C    1462700  1462791  ...  2.163961  2.163961  1.874410
# 4   E2F5_HUMAN.H11MO.0.B    1461300  1461399  ...  2.109352  2.109352  1.416897
# 5  TBX15_HUMAN.H11MO.0.D    1245100  1245199  ...  0.057167  0.057167 -0.164354
# 6    SP2_HUMAN.H11MO.0.A    1206100  1206199  ... -0.158145 -0.015642 -0.158145
# 7    SP1_HUMAN.H11MO.0.A    1206000  1206099  ...  0.113581  0.113581 -0.138450
# 8   UNC4_HUMAN.H11MO.0.D     808900   808999  ... -0.132150 -0.117586 -0.132150
# 9   NFIB_HUMAN.H11MO.0.D     781500   781500  ... -0.122356  0.009504 -0.122356
#
# [10 rows x 7 columns]
# Saving attribution scores...
# (2097152, 5)
# Mean change in target locus after inserting motif ZBT14_HUMAN.H11MO.0.C at pos 821100: 0.01
# Mean change in target locus after inserting motif PRRX2_HUMAN.H11MO.0.C at pos 1251700: 0.01
# Mean change in target locus after inserting motif ZBT14_HUMAN.H11MO.0.C at pos 1460900: 0.01
# Mean change in target locus after inserting motif ZBT14_HUMAN.H11MO.0.C at pos 1462700: 0.01
# Mean change in target locus after inserting motif E2F5_HUMAN.H11MO.0.B at pos 1461300: 0.01
# Mean change in target locus after inserting motif TBX15_HUMAN.H11MO.0.D at pos 1245100: -0.00
# Mean change in target locus after inserting motif SP2_HUMAN.H11MO.0.A at pos 1206100: -0.01
# Mean change in target locus after inserting motif SP1_HUMAN.H11MO.0.A at pos 1206000: -0.01
# Mean change in target locus after inserting motif UNC4_HUMAN.H11MO.0.D at pos 808900: -0.01
# Mean change in target locus after inserting motif NFIB_HUMAN.H11MO.0.D at pos 781500: 0.00

# %% [markdown]
# ### Mouse HOCOMOCO

# %%
! python seq_saliency_scores.py \
    --model /mnt/jinstore/Archive03/xxl1432/11.C.shark/models/31.Hsieh_WT_CTCF_ATAC_5kb_norm10_6tracks/models/deeploop_Hsieh_WT_5kb_norm_10_CTCF_ATAC_training_ctcf_atac_rad21_h3k4me3_h3k27ac_h3k36me3_h3k9me3_h3k27me3.ckpt \
    --chr chr11 \
    --start 31000000 \
    --seq ../cshark_data/data/mm10/dna_sequence \
    --bigwigs ctcf=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/ctcf.bw \
              atac=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/atac.bw \
    --target-locus "chr11:31760000-31860000_chr11:32380000-32480000" \
    --resolution 4096 \
    --matrix-size 512 \
    --ctcf-ko \
    --out-dir tmp \
    --meme-file /home/dmp131/C.Shark/src/cshark/static/HOCOMOCOv11_full_MOUSE_mono_meme_format.meme \
    --n-motifs 5
