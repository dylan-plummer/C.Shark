# %%
! python shah_predict.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/shah_10kb.ckpt \
    --chr chr1 \
    --start 36000000 \
    --seq ../cshark_data/data/mm10/dna_sequence \
    --out-dir outputs/shah_test \
    --contexts 1,1,1 2,1,0.4 2,1,1 3,1,1 1.2,7,0.2 1,1,1 1.2,3,1.2 0.8,7,0.5 0.8,3,3 \
    --context-names Untreated NIPBL_KO Rad21_50pct Rad21_30pct WAPL_NIPBL_KO Untreated PDS5AB_NIPBL_KO WAPL_KO PDS5AB_KO \
    --frames 30 \
    --bigwigs ctcf=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/ctcf.bw \
    atac=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/atac.bw \
    --target-locus chr1:36000000-38000000_chr1:36000000-38000000 \
    --resolution 8192 \
    --matrix-size 256
# Out:
# Using device: cuda
# Loading data for region chr1:36000000...
# Loading model...
# Using 12 encoder blocks based on target_mat_size=256.
# Using conditioning vector of size 3.
# Using 12 encoder blocks based on target_mat_size=256.
# Using conditioning vector of size 3.
# ['1,1,1', '2,1,0.4', '2,1,1', '3,1,1', '1.2,7,0.2', '1,1,1', '1.2,3,1.2', '0.8,7,0.5', '0.8,3,3']
# Generating frames: 100%|██████████████████████| 270/270 [02:36<00:00,  1.73it/s]
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-5)
# ...

# %%
! python shah_predict.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/shah_10kb.ckpt \
    --chr chr1 \
    --start 36000000 \
    --seq ../cshark_data/data/mm10/dna_sequence \
    --out-dir outputs/shah_test_fig3 \
    --contexts 1,1,1 0.8,7,0.5 0.8,3,3 \
    --context-names Untreated WAPL_KO PDS5AB_KO \
    --frames 60 \
    --bigwigs ctcf=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/ctcf.bw \
    atac=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/atac.bw \
    --target-locus chr1:36000000-38000000_chr1:36000000-38000000 \
    --resolution 8192 \
    --matrix-size 256
# Out:
# Using device: cuda
# Loading data for region chr1:36000000...
# Loading model...
# Using 12 encoder blocks based on target_mat_size=256.
# Using conditioning vector of size 3.
# Traceback (most recent call last):
#   File "/home/dmp131/anaconda3/envs/cshark/lib/python3.12/site-packages/cshark/inference/utils/model_utils.py", line 80, in load_default
#     load_checkpoint(model, model_path)
#   File "/home/dmp131/anaconda3/envs/cshark/lib/python3.12/site-packages/cshark/inference/utils/model_utils.py", line 229, in load_checkpoint
#     model.load_state_dict(model_weights)
#   File "/home/dmp131/anaconda3/envs/cshark/lib/python3.12/site-packages/torch/nn/modules/module.py", line 2593, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for CSharkUniversalModel:
# ...

# %%
! python shah_predict.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/shah_10kb.ckpt \
    --chr chr1 \
    --start 36000000 \
    --seq ../cshark_data/data/mm10/dna_sequence \
    --out-dir outputs/shah_test \
    --contexts 1,1,1 2,1,0.4 2,1,1 3,1,1 \
    --context-names Untreated NIPBL_KO RAD21_50% RAD_21_30% \
    --frames 60 \
    --bigwigs ctcf=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/ctcf.bw \
    atac=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/atac.bw \
    --target-locus chr1:36000000-38000000_chr1:36000000-38000000 \
    --resolution 8192 \
    --matrix-size 256
# Out:
# Using device: cuda
# Loading data for region chr1:36000000...
# Loading model...
# Using 12 encoder blocks based on target_mat_size=256.
# Using conditioning vector of size 3.
# Using 12 encoder blocks based on target_mat_size=256.
# Using conditioning vector of size 3.
# ['1,1,1', '2,1,0.4', '2,1,1', '3,1,1']
# Generating frames: 100%|██████████████████████| 240/240 [02:12<00:00,  1.81it/s]
# ffmpeg version 8.0 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.3.0 (conda-forge gcc 14.3.0-5)
# ...
