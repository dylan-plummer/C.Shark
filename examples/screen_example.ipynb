# %%
! python ../src/cshark/inference/perturb.py \
    --celltype hESC_WT_50pct \
    --outname baseline \
    --chr chr7 \
    --start 23000000 \
    --model ../checkpoints/deeploop_hESC_EP_CTCF_fix.ckpt \
    --seq ../cshark_data/data/hg19/dna_sequence \
    --screen-start 23200000 \
    --screen-end 23700000 \
    --ko-width 10000 \
    --step-size 10000 \
    --ko ctcf \
    --ko-mode knockout \
    --region chr7:23200000-23700000 \
    --min-val-pred 0.5 \
    --bigwigs ctcf=../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/ctcf.bw \
              h3k27ac=../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/h3k27ac.bw \
              h3k4me3=../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/h3k4me3.bw
# Out:
# Loading ../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/h3k27ac.bw
# Loading ../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/h3k4me3.bw
# Number of genomic features: 3
# Screening...
# 100%|███████████████████████████████████████████| 50/50 [00:44<00:00,  1.12it/s]
# Window start: 23580000, Window end: 23590000
# Window start: 23690000, Window end: 23700000
# Window start: 23610000, Window end: 23620000
# Window start: 23460000, Window end: 23470000
# Window start: 23300000, Window end: 23310000

# %%
Image(filename='outputs/baseline_hESC_WT_50pct_chr7_22536424_ctcf_screen_tracks.png', width=300)

# %%
! python ../src/cshark/inference/perturb.py \
    --celltype hESC_WT_50pct \
    --outname baseline \
    --chr chr7 \
    --start 23000000 \
    --model ../checkpoints/deeploop_hESC_EP_CTCF_fix.ckpt \
    --seq ../cshark_data/data/hg19/dna_sequence \
    --region chr7:23200000-23700000 \
    --min-val-pred 0.5 \
    --bigwigs ctcf=../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/ctcf.bw \
              h3k27ac=../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/h3k27ac.bw \
              h3k4me3=../cshark_data/data/hg19/hESC_WT_50pct/genomic_features/h3k4me3.bw
