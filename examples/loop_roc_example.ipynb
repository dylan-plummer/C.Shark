# %%
! python ../src/cshark/inference/loop_roc.py \
    --cooler /mnt/jinstore/Archive03/xxl1432/11.C.shark/preprocessing/1.to_cooler/5.hESC_WT_50pct_5kb/hESC_WT_50pct_5kb_deeploop.cool \
    --pred /mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark/perturbation/7.hESC_WT_CTCF_ATAC_5kb_norm/1.full_chrom/outputs \
    --pred-col WT \
    --chrom chr11  # provide a single chromosome or ignore this argument to run all chromosomes
# Out:
# 100%|███████████████████████████████████████████| 72/72 [00:20<00:00,  3.45it/s]
# /home/dmp131/C.Shark/examples/../src/cshark/inference/loop_roc.py:157: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pixels_wt_dfs = pd.concat(pixels_wt_dfs).fillna(0)
# ...
# Processing chromosomes: 100%|█████████████████████| 1/1 [00:02<00:00,  2.12s/it]
# Cooler file created at: outputs/pred_WT_5kb.cool
# 100%|███████████████████████████████████████████| 20/20 [01:45<00:00,  5.27s/it]
# AUC: 0.954
# Figure(300x300)

# %%
from IPython.display import Image
Image('outputs/WT_roc_curve.png', width=300)

# %%
! python ../src/cshark/inference/loop_roc.py \
    --cooler /mnt/jinstore/Archive03/xxl1432/11.C.shark/preprocessing/1.to_cooler/6.hESC_KO_50pct_5kb/hESC_KO_50pct_5kb_deeploop.cool \
    --pred /mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark/perturbation/7.hESC_WT_CTCF_ATAC_5kb_norm/1.full_chrom/outputs \
    --pred-col KO \
    --chrom chr11
# Out:
# 100%|███████████████████████████████████████████| 72/72 [00:17<00:00,  4.04it/s]
# /home/dmp131/C.Shark/examples/../src/cshark/inference/loop_roc.py:157: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pixels_wt_dfs = pd.concat(pixels_wt_dfs).fillna(0)
# ...
# Processing chromosomes: 100%|█████████████████████| 1/1 [00:02<00:00,  2.21s/it]
# Cooler file created at: outputs/pred_KO_5kb.cool
# 100%|███████████████████████████████████████████| 20/20 [01:52<00:00,  5.62s/it]
# AUC: 0.855
# Figure(300x300)

# %%
Image('outputs/KO_roc_curve.png', width=300)
