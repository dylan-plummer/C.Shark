# %%
! python shah_optimize_with_gradients.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/shah_10kb_oe_density.ckpt \
    --chr chr1 \
    --start 38000000 \
    --end 62000000 \
    --seq ../cshark_data/data/mm10/dna_sequence \
    --out-dir outputs/Hsieh_WAPL_KO \
    --init-context 1,1,1 \
    --hic /mnt/jinstore/JinLab04/dmp131/cshark_data/data/mm10/Hsieh_wapl_ko/hic_matrix/chr1.npz \
    --bigwigs ctcf=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/ctcf.bw \
    atac=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/atac.bw \
    --resolution 8192 \
    --matrix-size 256 \
    --n-iter 100 \
    --viz
# Out:
# Using device: cuda
# Loading data from 38000000 to 62000000 with step 1000000...
# Loading Windows: 100%|██████████████████████████| 24/24 [00:40<00:00,  1.67s/it]
# Loaded 24 windows.
# Loading model...
# 0.3456749 7.6931176
# Starting optimization...
# Iteration 1/100, Avg Loss: 0.2218, Context: [[0.80475336 1.1962357  1.1958469 ]]
# Iteration 10/100, Avg Loss: 0.1517, Context: [[0.56982803 1.365221   1.0473653 ]]
# Iteration 20/100, Avg Loss: 0.1476, Context: [[0.5075863 0.9033185 0.9571677]]
# Iteration 30/100, Avg Loss: 0.1460, Context: [[0.42883056 0.52871037 0.87055194]]
# Iteration 40/100, Avg Loss: 0.1459, Context: [[0.4220307  0.45441228 0.85646695]]
# Iteration 50/100, Avg Loss: 0.1459, Context: [[0.4189455 0.433684  0.8512849]]
# Iteration 60/100, Avg Loss: 0.1459, Context: [[0.41735062 0.44335887 0.8578405 ]]
# Iteration 70/100, Avg Loss: 0.1459, Context: [[0.41639668 0.4241243  0.853148  ]]
# ...

# %%
! python shah_optimize_with_gradients_multi_init.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/shah_10kb_oe_density.ckpt \
    --chr chr1 \
    --start 38000000 \
    --end 50000000 \
    --seq ../cshark_data/data/mm10/dna_sequence \
    --out-dir outputs/Hsieh_WAPL_KO \
    --hic /mnt/jinstore/JinLab04/dmp131/cshark_data/data/mm10/Hsieh_wapl_ko/hic_matrix/chr1.npz \
    --bigwigs ctcf=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/ctcf.bw \
    atac=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/atac.bw \
    --resolution 8192 \
    --matrix-size 256 \
    --n-iter 50 \
    --n-init 20 \
    --viz
# Out:
# Using device: cuda
# Loading data from 38000000 to 50000000 (step 1000000)...
# Loading Windows: 100%|██████████████████████████| 12/12 [00:28<00:00,  2.37s/it]
# Loaded 12 windows.
#
# --- Initialization 1 / 20 ---
# Init 1 Finished. Loss: 0.1215, Params: [3.62489  0.1      6.691435]
#
# --- Initialization 2 / 20 ---
# Init 2 Finished. Loss: 0.0971, Params: [3.0759568 2.4238892 7.871489 ]
#
# --- Initialization 3 / 20 ---
# Init 3 Finished. Loss: 0.1598, Params: [1.1316773  5.336392   0.31725627]
#
# --- Initialization 4 / 20 ---
# Init 4 Finished. Loss: 0.1607, Params: [1.2377119  6.2909617  0.25025865]
#
# --- Initialization 5 / 20 ---
# Init 5 Finished. Loss: 0.1854, Params: [1.6876097 6.6231103 0.5917123]
#
# --- Initialization 6 / 20 ---
# Init 6 Finished. Loss: 0.2632, Params: [3.2541842 4.4455748 0.1      ]
#
# --- Initialization 7 / 20 ---
# Init 7 Finished. Loss: 0.1607, Params: [1.2083837  6.1343074  0.22826996]
#
# --- Initialization 8 / 20 ---
# ...

# %%
! python shah_optimize_with_gradients_multi_init.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/shah_10kb_oe.ckpt \
    --chr chr7 \
    --start 126000000 \
    --seq ../cshark_data/data/mm10/dna_sequence \
    --out-dir outputs/shah_test \
    --hic /mnt/jinstore/JinLab04/dmp131/cshark_data/data/mm10/pds5ab_nipbl_rep2/hic_matrix/chr7.npz \
    --bigwigs ctcf=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/ctcf.bw \
    atac=/mnt/jinstore/JinLab03/xxl1432/HiCorr_Deeploop/11.C.shark_checkpoints/cshark_data/data/mm10/Hsieh_CTCF_WT_5kb_norm_10/genomic_features/atac.bw \
    --resolution 8192 \
    --matrix-size 256 \
    --n-iter 100 \
    --n-init 10 \
    --viz
# Out:
# 2025-11-10 10:29:05,797 - INFO - Using device: cuda
# 2025-11-10 10:29:05,797 - INFO - Loading data and model...
# 2025-11-10 10:29:06,249 - INFO - Model expects the following tracks: ['ctcf', 'atac']
# 2025-11-10 10:29:06,251 - INFO - Loading data for region chr7:126000000...
# Loading Hi-C data from: /mnt/jinstore/JinLab04/dmp131/cshark_data/data/mm10/pds5ab_nipbl_rep2/hic_matrix/chr7.npz
# 2025-11-10 10:29:08,098 - INFO - Loading model...
# 2025-11-10 10:29:12,019 - INFO - [Init 1/10] Starting optimization from: [1.4035894 3.7245197 1.3361943]
# 2025-11-10 10:29:28,652 - INFO - [Init 1/10] Finished. Final MSE: 0.166390, Final Params: [1.1554865 2.6707752 1.1351529], scale/bias: 1.0/0.0
# 2025-11-10 10:29:28,654 - INFO - [Init 2/10] Starting optimization from: [1.6241647 3.8164098 0.9304227]
# 2025-11-10 10:29:44,099 - INFO - [Init 2/10] Finished. Final MSE: 0.166592, Final Params: [1.2406775 3.0287802 1.0880011], scale/bias: 1.0/0.0
# ...

# %%
! python shah_optimize_with_gradients_multi_init.py \
    --model /mnt/jinstore/JinLab02/dmp131/C.Shark/checkpoints/shah_10kb_oe_density.ckpt \
    --chr chr11 \
    --start 31000000 \
    --seq ../cshark_data/data/hg19/dna_sequence \
    --out-dir outputs/shah_test_hESC \
    --hic /mnt/jinstore/JinLab02/dmp131/C.Shark/cshark_data/data/hg19/hESC_WT_10kb_ICE_OE/hic_matrix/chr11.npz \
    --bigwigs ctcf=/mnt/jinstore/JinLab02/dmp131/C.Shark/cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/ctcf.bw \
              atac=/mnt/jinstore/JinLab02/dmp131/C.Shark/cshark_data/data/hg19/hESC_WT_5kb_norm_10/genomic_features/atac.bw \
    --resolution 8192 \
    --matrix-size 256 \
    --n-iter 100 \
    --n-init 100 \
    --no-bounds \
    --ignore-diag 0 \
    --viz
# Out:
# 2025-11-11 15:54:01,801 - INFO - Using device: cuda
# 2025-11-11 15:54:01,801 - INFO - Loading data and model...
# 2025-11-11 15:54:03,794 - INFO - Model expects the following tracks: ['ctcf', 'atac']
# 2025-11-11 15:54:03,796 - INFO - Loading data for region chr11:31000000...
# Loading Hi-C data from: /mnt/jinstore/JinLab02/dmp131/C.Shark/cshark_data/data/hg19/hESC_WT_10kb_ICE_OE/hic_matrix/chr11.npz
# 2025-11-11 15:54:05,332 - INFO - Loading model...
# 2025-11-11 15:54:09,385 - INFO - [Init 1/100] Starting optimization from: [2.1169364 1.2673976 0.5442261]
# 2025-11-11 15:54:26,158 - INFO - [Init 1/100] Finished. Final MSE: 0.191602, Final Params: [0.60639334 0.280935   1.1738861 ], scale/bias: 1.0/0.0
# 2025-11-11 15:54:26,159 - INFO - [Init 2/100] Starting optimization from: [1.8445389 4.578219  2.9382548]
# 2025-11-11 15:54:41,563 - INFO - [Init 2/100] Finished. Final MSE: 0.214678, Final Params: [2.6192217  0.11152705 7.074955  ], scale/bias: 1.0/0.0
# ...
